# %%
import json
from datetime import datetime
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import collections
import matplotlib.ticker as plticker
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pydash
import tiktoken
from openai import OpenAI
import os
from api import ApiClient
from const import *
import re
from utils import *

# %load_ext autoreload
# %autoreload 2

sns.set_theme(style="darkgrid")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
client = ApiClient()

# %%
client.create(
    [
        client.make_msg(
            "system",
            "You are image descripto. Respond with json of this format: {'description': what you see, 'style': stylistics of the image}",
        ),
        client.make_msg(
            "user",
            "What's in this image?",
            get_image_url(
                "https://cdn.midjourney.com/ca13f713-b289-45ee-92fe-b1276a1dc833/0_3.webp"
            ),
        ),
    ],
    format=JSON_MODE,
)
# Out:
# '{"description":"The image features a stylized depiction of a young woman with vivid red hair and striking blue eyes. She is wearing a black bikini and posing with her arms raised behind her head, which accentuates her slender physique. The background is a plain, bright blue, emphasizing the subject.", "style":"The artwork is rendered in a digital painting style with smooth, detailed brushstrokes that give a soft, realistic texture to the hair and skin. The colors are vibrant, particularly the contrast between the red hair and blue background."}'

# %%
# Out:
# 'data:image/png;base64,...'
